# %%
#创建文件
def create__file(file_path,msg):
    f=open(file_path,'w+')
    f.write(msg)
    f.close

# %%
#!/usr/bin/env python3
# coding: utf-8
import xlrd

file_path="/Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/"

# 打开excel文件，创建一个workbook对象,book对象也就是fruits.xlsx文件,表含有sheet名
rbook = xlrd.open_workbook('/Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/业务数据库采集表清单.xlsx')

# sheets方法返回对象列表,[<xlrd.sheet.Sheet object at 0x103f147f0>]
rbook.sheets()

# xls默认有3个工作簿,Sheet1,Sheet2,Sheet3
rsheet = rbook.sheet_by_index(0)  # 取第一个工作簿

# 循环工作簿的所有行
for row in rsheet.get_rows():
    host = row[2]    #RDS实例
    db = row[3]      # 数据库名
    before = row[4]  #命名前缀
    table = row[5]   # 品名所在的列
    index = row[6]   # 品名所在的列
    
    host_name = host.value     #rds实例
    db_name = db.value         #库名
    before_name = before.value #前缀
    table_name = table.value   #表名
    col_list = index.value     #字段名
    # 打印
    if table_name == "表名":
        continue
    else:
        file_name = file_path + table_name + ".sh"
        msg = """
#!/bin/bash
host=""" + host_name + """
port=3306
username=datacenter
password=D45Z6p3k9x6hlN6U
opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"

db=""" + db_name + """
url=jdbc:mysql://$host:$port/$db${opts}
mysql_table=al_register_company_process
col_list=""" + col_list + """\n
hive_db=temp
hive_table='sap_'$mysql_table'_snap_dt'
hive_part=$(date +%Y%m%d)

sqoop import \
\n--connect $url \
\n--username $username \
\n--password $password \
\n--table $mysql_table \
\n--columns $col_list \
\n--direct \
\n--hive-import \
\n--hive-database $hive_db \
\n--hive-table $hive_table \
\n--hive-partition-key dt \
\n--hive-partition-value "$hive_part" \
\n--null-string '\\N' \
\n--null-non-string '\\N' \
\n--fields-terminated-by '^' \
\n--delete-target-dir \
\n--compression-codec org.apache.hadoop.io.compress.SnappyCodec \
\n-m 1"""
        create__file(file_name,msg)
        #print(file_name)
        print(file_name+ "\n" + db_name + "\n" + msg)
# Out:
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/rs_company.sh
# crm
#
#
# #!/bin/bash
# host=rdssrg18237a87a5060m3o.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=crm
#
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=id,name,province_id,city_id,area,type,discount,account,use_money,cash_money,rebate,rebate_use,cash_use,create_time,join_fee,join_status,remove_time,join_time,legal_name,legal_mobile,address,reward,reward_use,small_scale_fee,taxpayer_fee,free_month_count,partner_id,org_code,bank_code,sign_company_name,common_group_id,esign_legal_name,esign_optation_name,modify_time,del_flag
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/rs_order.sh
# crm
#
#
# #!/bin/bash
# host=rdssrg18237a87a5060m4o.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=crm
#
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=id,company_id,customer_id,order_type,order_number,acc_fee,extra_fee,total_fee,amount,paid_amount,outworker_number,is_zero,bill_number,status,type,create_id,create_name,create_time,channel_id,saler_id,saler_name,accoutant_id,accoutant_name,service_start_time,service_end_time,customer_type,lading_time,confirm_time,confirm_name,examine_status,contract_type,service_type,sign_time,is_end,deduct_amount,deduct_type,from_type,updated_at,is_old_customer,valid_count,accouting_company_id,update_time,other_content,accouting_company_time,renew_state,old_order_id,renew_confirm_time,esign_statue,esign_time,modify_time,del_flag
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/rs_product.sh
# crm
#
#
# #!/bin/bash
# host=rdssrg18237a87a5060m5o.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=crm
#
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=id,cid,sku_type,name,icon,service_time,service_unit,service_desc,create_id,create_name,create_time,update_time,is_send
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/rys_contract.sh
# crm_order
#
# #!/bin/bash
# host=rm-bp188tokn74cg6e74so.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=crm_order
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=id,customer_company_id,order_type,contract_no,order_id,order_number,acc_fee,extra_fee,total_fee,amount,paid_amount,outworker_number,is_zero,bill_number,status,type,customer_id,service_company_id,accounting_company_name,create_id,create_name,create_time,channel_id,saler_id,saler_name,accoutant_id,accoutant_name,service_start_time,service_end_time,customer_type,lading_time,confirm_time,confirm_name,examine_status,contract_type,service_type,sign_time,is_end,deduct_amount,deduct_type,from_type,is_old_customer,valid_count,accouting_company_id,update_time,other_content,accouting_company_time,renew_state,old_contract_id,renew_confirm_time,modify_time,del_flag
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/rys_contract_sku.sh
# crm_order
#
# #!/bin/bash
# host=rm-bp188tokn74cg6e75so.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=crm_order
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=id,contract_id,company_id,service_id,service_cycle,surrender_fee,profit_fee,total_fee,cost_price,create_at,remark,service_num,is_send,service_unit,service_type,create_time,modify_time,del_flag
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/rys_order.sh
# crm_order
#
# #!/bin/bash
# host=rm-bp188tokn74cg6e76so.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=crm_order
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=id,order_number,uid,contact_name,mobile,product_name,province,city,area,source,is_advance,total_amount,payable_amount,paid_amount,status,follow_status,remark,third_order_number,third_order_info,batch_import_no,staff_id,staff_name,staff_leader,staff_department,create_at,update_at,service_provider_id,join_company_id,deleted,import_user_id,contract_id,service_status,company_id,service_type,is_build_account,duration,pay_time,clue_intention_id,is_renew,third_status,create_time,modify_time,del_flag
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/rys_order_clue.sh
# crm_order
#
# #!/bin/bash
# host=rm-bp188tokn74cg6e77so.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=crm_order
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=id,order_id,cat_id,clue_id,create_time,modify_time,del_flag
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/rys_order_contract.sh
# crm_order
#
# #!/bin/bash
# host=rm-bp188tokn74cg6e78so.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=crm_order
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=id,order_id,contract_id,contract_no,create_time,modify_time,del_flag
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/rys_order_customer.sh
# crm_order
#
# #!/bin/bash
# host=rm-bp188tokn74cg6e79so.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=crm_order
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=id,order_id,customer_id,create_time,modify_time,del_flag
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/rys_order_log.sh
# crm_order
#
# #!/bin/bash
# host=rm-bp188tokn74cg6e80so.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=crm_order
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=id,order_id,create_id,create_name,type,content,extra,create_at,create_time,modify_time,del_flag
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/rys_order_product.sh
# crm_order
#
# #!/bin/bash
# host=rm-bp188tokn74cg6e81so.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=crm_order
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=id,order_id,product_id,spu_id,num,price,spu_name,product_name,product_type,attribute,province,city,area,status,extra,create_time,modify_time,del_flag
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/rys_service_company_statistics.sh
# crm_order
#
# #!/bin/bash
# host=rm-bp188tokn74cg6e82so.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=crm_order
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=id,service_company_id,service_company_name,month_contract_num,total_contract_num,created_at,updated_at,create_time,modify_time,del_flag
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/rys_area.sh
# crm
#
# #!/bin/bash
# host=rm-bp188tokn74cg6e83so.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=crm
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=rys_area_id,rys_area_pid,rys_area_name,rys_area_type,created_time,updated_time
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/rys_clue.sh
# crm
#
# #!/bin/bash
# host=rm-bp188tokn74cg6e84so.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=crm
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=id,company_id,channel_type,clue_type,department_id,intention_id,from_type,resource_type,customer_sex,customer_name,city_id,province_id,area_id,extra_content,consult_type,created_time,creator_id,creator_name,follow_status,dist_status,transfer_status,follow_id,follow_name,updated_time,clue_domain,is_back,transform_type,consult_count,follow_count,type,previous_follow_id,previous_follow_name,origin_company_id,mobile,order_num,intention_biz_id,clue_user_info_id,sub_company_follow_count,app_id,enterprise_id
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/rys_clue_action.sh
# crm
#
# #!/bin/bash
# host=rm-bp188tokn74cg6e85so.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=crm
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=id,clue_id,from_type,resource_type,city_id,province_id,created_time,area_id,ip_address,extra_content,consult_type,type,updated_time
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/rys_clue_category.sh
# crm
#
# #!/bin/bash
# host=rm-bp188tokn74cg6e86so.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=crm
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=id,name,parent_id,extra_content,sorts,app_id,created_time,updated_time
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/rys_clue_company.sh
# crm
#
# #!/bin/bash
# host=rm-bp188tokn74cg6e87so.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=crm
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=id,clue_id,clue_user_info_id,mobile,company_name,company_id,tax_payer_type,company_type,industry_id,province_id,city_id,area_id,address,legal_name,legal_sex,register_time,created_time,creator_id,creator_name,social_credit_code,website,app_id,updated_time,registered_capital,manage_time_upper_limit,legal_id_card_number,legal_id_card_address,company_old_name,manage_scope
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/rys_clue_operate.sh
# crm
#
# #!/bin/bash
# host=rm-bp188tokn74cg6e88so.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=crm
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=id,company_id,op_content,operate_type,clue_id,created_time,creator_id,creator_name,to_follow_id,clue_user_info_id,updated_time,from_follow_id,enterprise_id
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/rys_clue_relation.sh
# crm
#
# #!/bin/bash
# host=rm-bp188tokn74cg6e89so.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=crm
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=id,clue_belong_id,clue_id,checked,created_time,updated_time
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/rys_clue_user_info.sh
# crm
#
# #!/bin/bash
# host=rm-bp188tokn74cg6e90so.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=crm
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=id,mobile,customer_sex,customer_name,city_id,province_id,area_id,order_num,extra_content,consult_count,created_time,ding_group_id,creator_id,creator_name,app_id,updated_time
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/rys_plan.sh
# crm
#
# #!/bin/bash
# host=rm-bp188tokn74cg6e91so.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=crm
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=id,solution_biz_id,intention_biz_id,remark,plan,created_time,updated_time,creator_id,biz_type,plan_status,app_id,company_id
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/t_accounting_company.sh
# agency
#
# #!/bin/bash
# host=rm-bp188tokn74cg6e92so.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=agency
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=id,group_id,agency_id,operator_id,platform_user_id,platform_username,company_name,legal_person,contract_time,province_code,province_name,city_code,city_name,address,social_credit_code,contract_code,contract_images,contact,contact_number,status,account_tool_name,stock_customer_num,gmt_created,gmt_modified
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/account_info.sh
# sap_system
#
# #!/bin/bash
# host=rm-bp178y3r7v1f6zacq.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=sap_system
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=account_id,account_name,start_year,start_month,account_stand,subject_level,subject_rule,company_id,local_cur,account_industry,create_time,update_time,create_user,update_user,reclassification,stop_service_time,service_status,service_month,old_subject_rule,act_source,act_confirm,act_check_status,del_flag
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/account_status_info.sh
# sap_system
#
# #!/bin/bash
# host=rm-bp178y3r7v1f7zacq.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=sap_system
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=account_status_id,account_year,account_month,current_status,account_id,create_time,update_time,create_user,update_user,is_check,del_flag
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/act_assets.sh
# sap_system
#
# #!/bin/bash
# host=rm-bp178y3r7v1f8zacq.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=sap_system
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=assets_id,account_id,assets_code,assets_name,assets_class,assets_model,assets_amount,assets_use_dep,assets_supplier,assets_start_date,assets_register_date,assets_subject_ljzj,assets_subject_zjfy,assets_subject_zcql,current_dep_flag,assets_meta_value,assets_residual_rate,assets_net_salvage,assets_estimated_usage_month,assets_usage_month,assets_remaining_month,assets_accumulated_dep,assets_year_accumulated_dep,assets_after_accumulated_dep,assets_impairment_value,assets_monthly_dep,assets_state,assets_change_category_code,temp_field1,depreciation,assets_initial_net_value,remarks,voucher_id,creat_date,update_date,creat_user,update_user,assets_act_line_dep,assets_is_one_fee,parent_id
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/act_auxiliary_balance.sh
# sap_system
#
# #!/bin/bash
# host=rm-bp178y3r7v1f9zacq.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=sap_system
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=act_auxiliary_balance_id,act_subject_id,account_id,account_year,account_month,subject_auxiliary_type,auxiliary_data_id,debit_value,credit_value,debit_value_foreign,credit_value_foreign,currency,exchange,auxiliary_num_credit,auxiliary_num_debit,auxiliary_price,auxiliary_price_foreign,create_time,update_time,create_user,update_user
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/act_balance.sh
# sap_system
#
# #!/bin/bash
# host=rm-bp178y3r7v1f10zacq.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=sap_system
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=act_balance_id,act_subject_id,account_id,account_year,account_month,debit_value,credit_value,debit_value_foreign,credit_value_foreign,currency,exchange,auxiliary_num_credit,auxiliary_num_debit,auxiliary_price,auxiliary_price_foreign,create_time,update_time,create_user,update_user
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/act_contract.sh
# sap_system
#
# #!/bin/bash
# host=rm-bp178y3r7v1f11zacq.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=sap_system
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=contract_id,contract_number,contract_contacts_name,contract_contacts_phone,company_id,company_name,contract_survey_time,create_time,update_time,create_user,update_user,group_id,php_contract_id,from_type,is_cancel,contract_amount,is_renewal,is_refund,contractor,renewal_time,contract_status,check_status,old_php_contract_id,on_line_flag,pay_time,modify_time,del_flag,audit_user_id,audit_user_name,allocation_time,allocation_process_flag,allocation_flag
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/act_contract_renewal.sh
# sap_system
#
# #!/bin/bash
# host=rm-bp178y3r7v1f12zacq.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=sap_system
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=renewal_id,renewal_status,renewal_user_id,renewal_time,act_contract_id,rule_type,update_time,create_time,contract_number,service_time_end,service_time_begin,service_user_id,service_product,contract_amount,check_desc,apply_date,php_contract_id,apply_user_id,opera_status,refuse_reason,reject_reason,bill_submit_date,audit_user_id,order_id,modify_time,del_flag
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/act_contract_service.sh
# sap_system
#
# #!/bin/bash
# host=rm-bp178y3r7v1f13zacq.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=sap_system
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=act_contract_service_id,service_type,service_status,service_progress,contract_id,auditor_id,create_time,update_time,create_user,update_user,continue_service_month,service_start_year,service_start_month,executor_id,service_month,modify_time,del_flag
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/act_contract_service_matter.sh
# sap_system
#
# #!/bin/bash
# host=rm-bp178y3r7v1f14zacq.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=sap_system
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=contract_service_matter_id,field_matter_id,contract_service_id,distributor_type,distributor_id,executor_type,executor_id,closing_date,reminder_type,create_time,update_time,create_user,update_user,service_matter_number,service_matter_status,field_matter_name
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/act_contract_service_matter_current.sh
# sap_system
#
# #!/bin/bash
# host=rm-bp178y3r7v1f15zacq.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=sap_system
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=contract_service_matter_current_id,contract_service_matter_id,contract_service_id,create_user,create_time,audit_time,done_time,transfer_accountant_id,already_remind,service_origin_matter_id,process_type,record_create_time,record_update_time
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/act_contract_service_origin_matter.sh
# sap_system
#
# #!/bin/bash
# host=rm-bp178y3r7v1f16zacq.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=sap_system
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=contract_service_origin_matter_id,act_contract_service_id,act_field_matter_id,create_time,update_time,create_user,update_user,other_content,fulfill_workflow_id
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/act_field_matter.sh
# sap_system
#
# #!/bin/bash
# host=rm-bp178y3r7v1f17zacq.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=sap_system
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=field_matter_id,matter_group,matter_name,is_release,standard_price,is_use,create_user,update_user,create_time,update_time,group_id
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/act_field_matter_process.sh
# sap_system
#
# #!/bin/bash
# host=rm-bp178y3r7v1f18zacq.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=sap_system
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=field_matter_process_id,field_matter_id,process_order,process_content
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/act_invoice_collection.sh
# sap_system
#
# #!/bin/bash
# host=rm-bp178y3r7v1f19zacq.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=sap_system
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=task_id,company_id,task_status,total_num,file_url_list,create_time,update_time,platform,account_id,start_date,end_date,user_id
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/act_invoice_company.sh
# sap_system
#
# #!/bin/bash
# host=rm-bp178y3r7v1f20zacq.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=sap_system
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=act_invoice_company_id,act_invoice_data_type,temporary_invoice_id,act_invoice_data_id,act_invoice_data_name,taxpayer_identification_number,address_and_mobile,opening_bank_and_account_number,deduction_state_or_billing_type,deduction_method_or_collection_method,remarks,cur_auxiliary_flag,currency_id,currency_rate,create_time,update_time,create_user,update_user,deduction_month
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/act_invoice_detail.sh
# sap_system
#
# #!/bin/bash
# host=rm-bp178y3r7v1f21zacq.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=sap_system
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=act_invoice_detail_id,temporary_invoice_id,business_type,invoice_item,stock_info_id,taxation_method_type,specification_type,unit,num,price,tax_rate,tax_amount,total_price_tax,act_invoice_info_id,create_time,update_time,create_user,update_user,stock_info_unit,original_currency_value,rate,cash_type,total_sum,invoice_item_old
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/act_invoice_info.sh
# sap_system
#
# #!/bin/bash
# host=rm-bp178y3r7v1f22zacq.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=sap_system
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=act_invoice_info_id,temporary_invoice_id,act_invoice_type,act_invoice_specific_type,act_invoice_code,act_invoice_number,act_invoice_current_authen_flag,act_invoice_date,account_id,account_year,account_month,act_invoice_num,act_invoice_company_id,act_voucher_id,create_time,update_time,create_user,update_user,complement_state,unit_name,amount_received,act_subject_id,act_subject_name,act_subject_code,cash_type,total_sum,remarks,act_invoice_state,source
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/act_invoice_record_file_detail.sh
# sap_system
#
# #!/bin/bash
# host=rm-bp178y3r7v1f23zacq.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=sap_system
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=act_invoice_record_file_detail_id,act_invoice_record_file_id,act_invoice_record_id,fpdm,fphm,kprq,fpnr,je,se,jshj,other_content
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/act_notice.sh
# sap_system
#
# #!/bin/bash
# host=rm-bp178y3r7v1f24zacq.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=sap_system
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=notice_id,notice_year,notice_month,notice_title,notice_content,create_time,create_user,source_type,notice_url
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/act_start_balance.sh
# sap_system
#
# #!/bin/bash
# host=rm-bp178y3r7v1f25zacq.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=sap_system
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=act_start_balance_id,act_subject_id,account_id,account_year,account_month,start_balance,debit_sum,credit_sum,year_start_balance,start_balance_foreign,debit_sum_foreign,credit_sum_foreign,year_start_balance_foreign,currency,exchange,auxiliary_num_debit,auxiliary_num_credit,auxiliary_num_start,auxiliary_price,auxiliary_price_foreign,create_time,update_time,create_user,update_user
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# ...
# sap_system
#
# #!/bin/bash
# host=rm-bp178y3r7v1f47zacq.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=sap_system
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=id,contract_id,paper_contract_no,third_order_no,partner_order_no,contract_content,contract_type,service_type,sign_type,service_start_date,service_end_date,submit_order_time,moving_account_channel,remark,create_time,modify_time,del_flag,third_company_info
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/rys_contract_log.sh
# sap_system
#
# #!/bin/bash
# host=rm-bp178y3r7v1f48zacq.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=sap_system
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=id,contract_id,content,user_id,user_name,scene,del_flag,create_time,modify_time
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/rys_order.sh
# sap_system
#
# #!/bin/bash
# host=rm-bp178y3r7v1f49zacq.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=sap_system
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=id,order_no,order_title,order_amount,order_pay_time,order_status,create_user_id,create_user_name,sale_user_id,sale_user_name,prov_id,city_id,area_id,del_flag,create_time,modify_time
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/rys_order_product_sku_snapshot.sh
# sap_system
#
# #!/bin/bash
# host=rm-bp178y3r7v1f50zacq.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=sap_system
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=id,order_sub_id,sku_id,sku_name,cat_id,cat_code,sku_desc,status,price,sku_service_cycle,sku_service_unit,is_send,sku_type,create_time,modify_time,del_flag
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/rys_order_sub.sh
# sap_system
#
# #!/bin/bash
# host=rm-bp178y3r7v1f51zacq.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=sap_system
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=id,order_id,order_sub_title,product_id,product_name,product_number,product_type,product_type_name,sale_price,discount_price,product_price,total_price,deal_price,order_sub_status,remark,del_flag,create_time,modify_time
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/rys_order_sub_contract.sh
# sap_system
#
# #!/bin/bash
# host=rm-bp178y3r7v1f52zacq.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=sap_system
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=order_sub_contract_id,order_sub_id,contract_id
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/sys_area.sh
# sap_system
#
# #!/bin/bash
# host=rm-bp178y3r7v1f53zacq.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=sap_system
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=sys_area_id,sys_area_pid,sys_area_name,sys_area_type
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/tax_info.sh
# sap_system
#
# #!/bin/bash
# host=rm-bp178y3r7v1f54zacq.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=sap_system
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=tax_id,account_id,company_id,tax_report_type_id,tax_type_id,declare_type,declare_way,final_declare_time,create_time,update_time,default_flag,tax_qualify,agent_person_name,agent_person_idcard,tax_agent_name,tax_agent_pwd
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/tax_info_report_type.sh
# sap_system
#
# #!/bin/bash
# host=rm-bp178y3r7v1f55zacq.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=sap_system
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=tax_report_type_id,account_id,company_id,tax_id,tax_report_type_name,tax_report_type_code,tax_report_type_form_name,tax_report_type_form_code,declare_way,is_submit,create_time,update_time,tax_qualify
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/tax_progress_info.sh
# sap_system
#
# #!/bin/bash
# host=rm-bp178y3r7v1f56zacq.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=sap_system
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=tax_progress_info_id,company_id,account_id,tax_declare_type,tax_declare_status,tax_declare_quarter,tax_declare_year,tax_declare_month,user_id,tax_type_id,tax_report_type_id,tax_status,tax_amount,tax_fail_reason,create_time,create_user,update_time,update_user,task_id,task_create_time,confirm_status,fetch_number_status,screen_shot,rpa_task_id,tax_action_type,task_end_time
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/tax_report_detail.sh
# sap_system
#
# #!/bin/bash
# host=rm-bp178y3r7v1f57zacq.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=sap_system
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=tax_report_detail_id,company_id,tax_report_code,tax_report_detail,declare_way,tax_report_year,tax_report_month,tax_report_day,create_time,update_time,create_user,update_user
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/tax_report_fetch_detail.sh
# sap_system
#
# #!/bin/bash
# host=rm-bp178y3r7v1f58zacq.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=sap_system
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=tax_report_fetch_detail_id,company_id,tax_report_code,tax_report_detail,declare_way,tax_report_year,tax_report_month,tax_report_day,create_time,update_time,create_user,update_user
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/user_comp_map.sh
# sap_system
#
# #!/bin/bash
# host=rm-bp178y3r7v1f59zacq.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=sap_system
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=data_id,user_id,company_id,role_id,create_time,update_time,create_user,update_user,old_user_id
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/user_feedback.sh
# sap_system
#
# #!/bin/bash
# host=rm-bp178y3r7v1f60zacq.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=sap_system
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=feedback_id,account_id,user_id,note,create_time,update_time
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1
# /Users/taoxuefeng/Desktop/work/myself_sql/数据同步/ods改造/ods数据同步/user_info.sh
# sap_system
#
# #!/bin/bash
# host=rm-bp178y3r7v1f61zacq.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
#
# db=sap_system
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=user_id,user_name,user_pwd,create_time,real_name,update_time,create_user,update_user,user_state,head_url,mobile,email,user_type,from_type,area_id,account_num,last_login_time,old_trial_user_flag,modify_time,del_flag
#
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date +%Y%m%d)
#
# sqoop import
# --connect $url
# --username $username
# --password $password
# --table $mysql_table
# --columns $col_list
# --direct
# --hive-import
# --hive-database $hive_db
# --hive-table $hive_table
# --hive-partition-key dt
# --hive-partition-value "$hive_part"
# --null-string '\N'
# --null-non-string '\N'
# --fields-terminated-by '^'
# --delete-target-dir
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec
# -m 1

# %%
print(msg)
# Out:
# !/bin/bash
# host=rm-bp178y3r7v1f6zacq.mysql.rds.aliyuncs.com
# port=3306
# username=datacenter
# password=D45Z6p3k9x6hlN6U
# opts="?tinyInt1isBit=false&zeroDateTimeBehavior=round&useSSL=false&autoReconnect=true"
# db=sap_system
# url=jdbc:mysql://$host:$port/$db${opts}
# mysql_table=al_register_company_process
# col_list=register_company_process_id,ic_audit_result,document_upload,engraving_status,is_postal_signature,steps_number,contract_service_matter_id,third_status,confirmation_sheet_url,original_scanner_url,service_origin_matter_id,correction_notice,contact_client_flag,confirm_doc_flag,confirm_doc_remark,audit_fail_reason_type,audit_fail_reason_remark,aic_submitname_date,aic_approved_date,get_licence_date,social_credit_code,companyname_inbusiness_license,business_license_url,engraving_finish_date,postal_sign_url,create_time,modify_time,del_flag
# hive_db=temp
# hive_table='sap_'$mysql_table'_snap_dt'
# hive_part=$(date -d "1 days ago" +%Y%m%d)
# sqoop import \
# --connect $url \
# --username $username \
# --password $password \
# --table $mysql_table \
# --columns $col_list \
# --direct \
# --hive-import \
# --hive-database $hive_db \
# --hive-table $hive_table \
# --hive-partition-key dt \
# --hive-partition-value "$hive_part" \
# --null-string '\N' \
# --null-non-string '\N' \
# --fields-terminated-by '^' \
# --delete-target-dir \
# --compression-codec org.apache.hadoop.io.compress.SnappyCodec \
# -m 1
